# %%
#ここには脳波計の数値を示す

# %%
path="EEG6-4.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm

# %%
#脳波を羅列する
#実際にはobs, time, Delta, Theta, Alpha1, Alpha2, Beta1, Beta2, Gamma1, Gamma2, Attention, Meditation, Derived, totPwr, CLASSを並べる

# %%
columns=["obs", "time", "Delta", "Theta", "Alpha1", "Alpha2", "Beta1", "Beta2", "Gamma1", "Gamma2", "Attention", "Meditation", "Derived", "totPwr", "class" ]
sampling_rate=512
df=None

reader = pd.read_csv(path, encoding="SHIFT_JIS",header=None,names=columns)
reader=reader.drop(0,axis=0)#一行目はいらない

# %%
print(reader)
# Out:
#      obs    time     Delta     Theta  Alpha1  Alpha2    Beta1   Beta2  Gamma1  \
# 1      1     3.9    323822     68195   34413   28204    11249   22402    9500
# 2      2     4.9    539154    140293   89614   10324    30660   49081   18763
# 3      3     5.9   2342051   1012790   29527   85358   102555   81212   12020
# 4      4     7.0    129790     88120    4383   10703     5479    6645    2826
# 5      5     7.9   1211453    173028    7533    9430    11699   21605    8961
# ..   ...     ...       ...       ...     ...     ...      ...     ...     ...
# 441  441   447.9     92415     12522    1644    1566     1868    2000     891
# 442  442   448.9     66905     20621    3910    8087     1440    7725    1373
# 443  443   449.9   1135421     36941    2484   21280    18905    9943    8448
# 444  444   450.9    240789    960454   23542   78046    32734   51383   42657
# 445  445   450.9    381326     45861   12980   10718    19731   10945    7125
#
#      Gamma2 Attention Meditation Derived    totPwr class
# 1      8339        NA         NA      NA    506124    X*
# 2     10474        NA         NA      NA    888363    X*
# 3     11953        NA         NA      NA   3677466    X*
# 4      5813        30         37      NA    253759    X*
# 5      3898        35         26      NA   1447607    X*
# ..      ...       ...        ...     ...       ...   ...
# 441     379        26         20      NA    113285     X
# 442     968        40         21      NA    111029     X
# 443    9525        57         30      NA   1242947     X
# 444   10300        43         26      NA   1439905     X
# 445    3157        44         30      NA    491843     X
#
# [445 rows x 15 columns]

# %%
##Deltaを変換する
df_D=[]
#Deltaを格納
df_D.append(reader.Delta)
print(df_D)
# Out:
# [1        323822
# 2        539154
# 3       2342051
# 4        129790
# 5       1211453
#          ...
# 441       92415
# 442       66905
# 443     1135421
# 444      240789
# 445      381326
# Name: Delta, Length: 445, dtype: object]

# %%
#objectになっているのでintに変換
df_D=np.array(df_D,dtype=np.int64)
#二次元配列はグラフにしてくれないので１次元にする
df_D=df_D.flatten()

# %%
#中身の確認
print(df_D)
# Out:
# [ 323822  539154 2342051  129790 1211453 1741793 1514272  156692   17846
#   202734  412531  859238  509040  181185  743582 1487283  814296  185967
#   135013 1657559  144538  289336  489753  147420  120147   79629  130424
#   117259   38552  993991 1503845  831134  428523  385807 1502857  453412
#   160119  307349  193284  955661  374017   97941   99045   74982  306770
#   477807  177615  500628  211801   92738  453124 1059295   82431  115792
#   158665  152397  392410  158198  129874   22987  146841  112946  160248
#   278188   52405  744870   85592  387451   79290  192359   38266  303766
#   655319  138473 1357303  129297   86321  367896  278305  107870 1077895
#   339125  117178 1794871   81043  278189  165480  488048  640838   72408
#   125892   53265 1015733  923510  348935 1051176   11254  485976  117769
#  1164735  267182 1165654  122732 2491926   76806  143390  407986  148756
#   131285  692467   44357  303159   73984   36317  241413   76709  318061
#   140386   54218   93701   42140  710908   87949  102083   23839   77907
#   365471  114251  521283  118138  105804   59404   65627  729942   83650
#   394616  390641   47332  130763  288555  473664  385516   97930  743811
#   617800  653927  333068  262194 1942638   85106   40933  109501   48421
#   397530   23579  404783   40368  520249  503951    9644  652092   78539
#    57141  466508   70286   38574  567957   75724  946595 1420150 1854787
#   408527  804498  211206  105710  456011   15053 1469877   47022  232225
#   242952  181626  192813  157794  215434  120928  246466   55540  854819
#    93863  112652   24984  632225  478855  817367  107165  534194   64234
#   273927 1292091 2444922   14144  106697   72327  299997   75360   87375
#   677620   14865  171214  127651 1288926  138058  179659  477894  283071
#  1364119  160057   82643  142708  174593  200663   36791   93168   81869
#   102505  109989  380965  654447   84860  312454   72936  115765 1542640
#   107174  156652  437081  478469  120203  158549  164348  185898  707061
#    37629  232402   79025  402105  294936  541665   64472  212409 1154220
#    43333  776557   26287 1077581    6969  436702  445445  155977  308726
#   170171   77519  143643  351128   52854   29609  783299   81623  697829
#   415403   99903  138512   99603  533985   90167  183787 2096190  603429
#   114184  536959  266360   72746  141920   67057  317787  180994 2102639
#    77810   90541  546213   36810  561268  417984  199913  159774   27252
#   162560  577634  282524  955508   36573  124250  263903   45109   82159
#   344733   79712   53744  402300  399689  609854  527166  500551  296511
#   474268  515749  160450   82037  207547   34684   47906   57102   84780
#   138315  155576  161509  136959 1956607   87123  107461  122153  266471
#   351519   64679   16969  348545   34757   25145   38995   28366   92307
#   718612 1611085  693076  245025  163626  196469  107428   19370  741309
#  1094146  126644  413310  155065  359246   55337  270817  165800  401179
#   336921   38436   55662   66878 1460207   43567  280570   48029  101130
#    29054   38746 1241877 1121585  173552  382083  120792  107215  119863
#   120344  145227   94460  437570  103390   34390 2166566  303200  223301
#  1527568  285803  485680  144024  372328   88570   83245  975621  202253
#   207077   11703  243231   87576   23836  616082  945605  272554  110580
#   140166  367312  577616  356266  311842 1613595  314862  166974 1547572
#   276099   73248 1878365   87808   73622   94530 1487359  825867  972569
#  1469767   72813   30718   41764  103250  255202 3545564  561347  947103
#   171457  181636  231800  109145  311646  144632  200272  438622   92415
#    66905 1135421  240789  381326]

# %%
#グラフにする
plt.plot(df_D)

# %%
##timeも変換してDeltaと一緒に見えるようにする
df_t=[]
df_t.append(reader.time)
df_t=np.array(df_t,dtype=np.float64)
df_t=df_t.flatten()
##atten

# %%
plt.plot(df_t,df_D)
